# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
path = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
crime = pd.read_csv(path)
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime['Year'] = pd.to_datetime(crime['Year'])
crime['Year'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime = crime.set_index(crime['Year'] , drop=True)
crime.head()
# Out:
#                                                        Year  Population  \
# Year
# 1970-01-01 00:00:00.000001960 1970-01-01 00:00:00.000001960   179323175
# 1970-01-01 00:00:00.000001961 1970-01-01 00:00:00.000001961   182992000
# 1970-01-01 00:00:00.000001962 1970-01-01 00:00:00.000001962   185771000
# 1970-01-01 00:00:00.000001963 1970-01-01 00:00:00.000001963   188483000
# 1970-01-01 00:00:00.000001964 1970-01-01 00:00:00.000001964   191141000
#
#                                  Total  Violent  Property  Murder  \
# Year
# 1970-01-01 00:00:00.000001960  3384200   288460   3095700    9110
# 1970-01-01 00:00:00.000001961  3488000   289390   3198600    8740
# 1970-01-01 00:00:00.000001962  3752200   301510   3450700    8530
# 1970-01-01 00:00:00.000001963  4109500   316970   3792500    8640
# 1970-01-01 00:00:00.000001964  4564600   364220   4200400    9360
#
#                                Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# ...

# %%
crime.drop(columns= 'Year' , axis=1 , inplace=True)
crime.head()
# Out:
#                                Population  Violent  Property  Murder  \
# Year
# 1970-01-01 00:00:00.000001960   179323175   288460   3095700    9110
# 1970-01-01 00:00:00.000001961   182992000   289390   3198600    8740
# 1970-01-01 00:00:00.000001962   185771000   301510   3450700    8530
# 1970-01-01 00:00:00.000001963   188483000   316970   3792500    8640
# 1970-01-01 00:00:00.000001964   191141000   364220   4200400    9360
#
#                                Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# 1970-01-01 00:00:00.000001960          17190   107840              154320
# 1970-01-01 00:00:00.000001961          17220   106670              156760
# 1970-01-01 00:00:00.000001962          17550   110860              164570
# 1970-01-01 00:00:00.000001963          17650   116470              174210
# 1970-01-01 00:00:00.000001964          21420   130390              203050
#
#                                Burglary  Larceny_Theft  Vehicle_Theft
# Year
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime.drop(columns= 'Total' , axis=1 , inplace=True)

# %%
crime.columns
# Out:
# Index(['Year', 'Population', 'Violent', 'Property', 'Murder', 'Forcible_Rape',
#        'Robbery', 'Aggravated_assault', 'Burglary', 'Larceny_Theft',
#        'Vehicle_Theft'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
print(crime.index.year.unique())
# Out:
# Index([1970], dtype='int32', name='Year')

# %%
crime['decades'] = (crime.index.year // 10) * 10
crime['decades']
# Out:
# Year
# 1970-01-01 00:00:00.000001960    1970
# 1970-01-01 00:00:00.000001961    1970
# 1970-01-01 00:00:00.000001962    1970
# 1970-01-01 00:00:00.000001963    1970
# 1970-01-01 00:00:00.000001964    1970
# 1970-01-01 00:00:00.000001965    1970
# 1970-01-01 00:00:00.000001966    1970
# 1970-01-01 00:00:00.000001967    1970
# 1970-01-01 00:00:00.000001968    1970
# 1970-01-01 00:00:00.000001969    1970
# 1970-01-01 00:00:00.000001970    1970
# 1970-01-01 00:00:00.000001971    1970
# 1970-01-01 00:00:00.000001972    1970
# 1970-01-01 00:00:00.000001973    1970
# 1970-01-01 00:00:00.000001974    1970
# 1970-01-01 00:00:00.000001975    1970
# 1970-01-01 00:00:00.000001976    1970
# 1970-01-01 00:00:00.000001977    1970
# 1970-01-01 00:00:00.000001978    1970
# 1970-01-01 00:00:00.000001979    1970
# 1970-01-01 00:00:00.000001980    1970
# 1970-01-01 00:00:00.000001981    1970
# 1970-01-01 00:00:00.000001982    1970
# 1970-01-01 00:00:00.000001983    1970
# ...

# %%
df = crime.drop(columns='Population' )
group_by_decades = df.groupby('decades').sum()
group_by_decades
# Out:
#           Violent   Property  Murder  Forcible_Rape   Robbery  \
# decades
# 1970     65384309  517687418  952448        3999314  22904744
#
#          Aggravated_assault   Burglary  Larceny_Theft  Vehicle_Theft
# decades
# 1970               37464999  133320955      327797108       56573743

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?
